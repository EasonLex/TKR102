# %%
import sys
sys.path.append("./")   # 視你的目錄結構調整
from inspect_day import load_day

df, snap = load_day("Taipei", "2026-08-03")
# Out:
# 找到 2034 個檔案

# %%
bad = df[df["BusStatus"] == 2]
print(bad["PlateNumb"].nunique())
bad["PlateNumb"].value_counts().head(10)
# Out:
# 2
# PlateNumb
# EAL-0016    377
# EAL-1916    165
# Name: count, dtype: int64
