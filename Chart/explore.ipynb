# %%
import sys
sys.path.append("./")   # 視你的目錄結構調整
from inspect_day import load_day

df, snap = load_day("Taipei", "2026-08-03")
# Out:
# 找到 2034 個檔案

# %%
bad_speed = df[df["Speed"] > 100]
print(bad_speed["PlateNumb"].value_counts().head())
df[df["Azimuth"]==65535]["PlateNumb"].value_counts().head()
df[df["Azimuth"]==65535]["Speed"].value_counts().head()
# Out:
# PlateNumb
# 619-U5      32
# EAL-0080    10
# 558-U5       5
# EAL-3661     4
# KKA-2786     4
# Name: count, dtype: int64
# Speed
# 0    4088
# 1     801
# 2     465
# 3     302
# 4     204
# Name: count, dtype: int64
